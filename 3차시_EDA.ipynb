# %% [markdown]
# <a href="https://colab.research.google.com/github/yleessam/py_data_anal_lesson/blob/main/3%EC%B0%A8%EC%8B%9C_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## 데이터 불러오기

# %%
import pandas as pd
df = pd.read_csv('iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ##  1) 품종별로 그룹화 한 후 히스토그램 그리기

# %%
# 그룹화
df1 = df.groupby('variety')
df1.head()
# Out:
#      sepal.length  sepal.width  petal.length  petal.width     variety
# 0             5.1          3.5           1.4          0.2      Setosa
# 1             4.9          3.0           1.4          0.2      Setosa
# 2             4.7          3.2           1.3          0.2      Setosa
# 3             4.6          3.1           1.5          0.2      Setosa
# 4             5.0          3.6           1.4          0.2      Setosa
# 50            7.0          3.2           4.7          1.4  Versicolor
# 51            6.4          3.2           4.5          1.5  Versicolor
# 52            6.9          3.1           4.9          1.5  Versicolor
# 53            5.5          2.3           4.0          1.3  Versicolor
# 54            6.5          2.8           4.6          1.5  Versicolor
# 100           6.3          3.3           6.0          2.5   virginica
# 101           5.8          2.7           5.1          1.9   virginica
# ...

# %%
# 히스토그램 그리기
df1.hist()
# Out:
# variety
# Setosa        [[Axes(0.125,0.545217;0.336957x0.334783), Axes...
# Versicolor    [[Axes(0.125,0.545217;0.336957x0.334783), Axes...
# virginica     [[Axes(0.125,0.545217;0.336957x0.334783), Axes...
# dtype: object

# %% [markdown]
# ## 2) 품종별로 평균 , 중간값, 표준편차, 백분위 구하기

# %%
print(df1.mean())
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa             5.006        3.428         1.462        0.246
# Versicolor         5.936        2.770         4.260        1.326
# virginica          6.588        2.974         5.552        2.026

# %%
print(df1.median())
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa               5.0          3.4          1.50          0.2
# Versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %%
print(df1.std())
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa          0.352490     0.379064      0.173664     0.105386
# Versicolor      0.516171     0.313798      0.469911     0.197753
# virginica       0.635880     0.322497      0.551895     0.274650

# %%
print(df1.quantile())
# Out:
#             sepal.length  sepal.width  petal.length  petal.width
# variety
# Setosa               5.0          3.4          1.50          0.2
# Versicolor           5.9          2.8          4.35          1.3
# virginica            6.5          3.0          5.55          2.0

# %% [markdown]
# ## 3) 각 속성 별로 mean, trim mean, weighted mean, median 값 확인하기

# %%
from scipy import stats
import numpy as np
#평균
print("sepal.width mean:",df['sepal.width'].mean())
#절사평균
a=stats.trim_mean(df['sepal.width'],0.1)
print("trim mean:", a)
#가중평균
w = [i for i in range(0,150)]
b=np.average(df['sepal.width'],weights=w)
print("weighted mean:", b)
#중위값
print("median:",df['sepal.width'].median())
# Out:
# sepal.width mean: 3.0573333333333337
# trim mean: 3.0433333333333334
# weighted mean: 2.955758389261745
# median: 3.0

# %%
print("sepal.length")
print("mean:",df['sepal.length'].mean())
a1=stats.trim_mean(df['sepal.length'],0.1)
print("trim mean:", a1)
w1 = [i for i in range(0,150)]
b1=np.average(df['sepal.length'],weights=w1)
print("weighted mean:", b1)
print("median:",df['sepal.length'].median())
print("\n")
print("petal.width")
print("mean:",df['petal.width'].mean())
a2=stats.trim_mean(df['petal.width'],0.1)
print("trim mean:", a2)
w2 = [i for i in range(0,150)]
b2=np.average(df['petal.width'],weights=w2)
print("weighted mean:", b2)
print("median:",df['petal.width'].median())
print("\n")
print("petal.length")
print("mean:",df['petal.length'].mean())
a3=stats.trim_mean(df['petal.length'],0.1)
print("trim mean:", a3)
w3 = [i for i in range(0,150)]
b3=np.average(df['petal.length'],weights=w3)
print("weighted mean:", b3)
print("median:",df['petal.length'].median())
# Out:
# sepal.length
# mean: 5.843333333333334
# trim mean: 5.8083333333333345
# weighted mean: 6.18710514541387
# median: 5.8
#
#
# petal.width
# mean: 1.1993333333333336
# trim mean: 1.1841666666666668
# weighted mean: 1.5967337807606263
# median: 1.3
#
#
# petal.length
# mean: 3.7580000000000005
# trim mean: 3.7600000000000002
# weighted mean: 4.660572706935122
# median: 4.35

# %% [markdown]
# ## 4-1) 각 속성 별로 value counts 구하기

# %%
print("sepal length 값들의 갯수")
print(df['sepal.length'].value_counts())
# Out:
# sepal length 값들의 갯수
# 5.0    10
# 5.1     9
# 6.3     9
# 5.7     8
# 6.7     8
# 5.8     7
# 5.5     7
# 6.4     7
# 4.9     6
# 5.4     6
# 6.1     6
# 6.0     6
# 5.6     6
# 4.8     5
# 6.5     5
# 6.2     4
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 5.9     3
# 4.4     3
# 7.2     3
# 6.8     3
# 6.6     2
# 4.7     2
# 7.6     1
# 7.4     1
# 7.3     1
# 7.0     1
# 7.1     1
# 5.3     1
# 4.3     1
# 4.5     1
# 7.9     1
# Name: sepal.length, dtype: int64

# %%
print('sepal width')
print(df['sepal.width'].value_counts())
print('petal length')
print(df['petal.length'].value_counts())
print('petal width')
print(df['petal.width'].value_counts())
# Out:
# sepal width
# 3.0    26
# 2.8    14
# 3.2    13
# 3.4    12
# 3.1    11
# 2.9    10
# 2.7     9
# 2.5     8
# 3.5     6
# 3.3     6
# 3.8     6
# 2.6     5
# 2.3     4
# 3.6     4
# 3.7     3
# 2.4     3
# 2.2     3
# 3.9     2
# 4.4     1
# 4.0     1
# 4.1     1
# 4.2     1
# 2.0     1
# Name: sepal.width, dtype: int64
# petal length
# 1.4    13
# 1.5    13
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# 3.9     3
# 4.6     3
# 5.7     3
# 4.1     3
# 5.5     3
# 6.1     3
# 5.8     3
# 3.3     2
# 5.4     2
# 6.7     2
# 5.3     2
# 5.9     2
# 6.0     2
# 1.2     2
# 4.3     2
# 1.9     2
# 3.5     2
# 5.2     2
# 3.0     1
# 1.1     1
# 3.7     1
# 3.8     1
# 6.6     1
# 6.3     1
# 1.0     1
# 6.9     1
# 3.6     1
# 6.4     1
# Name: petal.length, dtype: int64
# petal width
# 0.2    29
# 1.3    13
# 1.8    12
# 1.5    12
# 1.4     8
# 2.3     8
# 1.0     7
# 0.4     7
# ...

# %% [markdown]
# ## 4-2) 각 속성 별로 value counts를 막대 그래프로 그리기

# %%
import matplotlib.pyplot as plt

f, axes = plt.subplots(4,1)
f.set_size_inches((10, 40))
plt.subplots_adjust(wspace = 0.3, hspace = 0.3)

ax1=df['sepal.width'].value_counts().plot(kind='barh',ax=axes[0],color='orange')
ax1.set_title('sepal width')
ax1.set_xlabel('sepal width')
ax1.set_ylabel('value counts')

ax2=df['sepal.length'].value_counts().plot(kind='barh',ax=axes[1])
ax2.set_title('sepal length')
ax2.set_xlabel('sepal length')
ax2.set_ylabel('value counts')

ax3=df['petal.width'].value_counts().plot(kind='barh',ax=axes[2],color='red')
ax3.set_title('petal width')
ax3.set_xlabel('petal width')
ax3.set_ylabel('value counts')

ax4=df['petal.length'].value_counts().plot(kind='barh',ax=axes[3],color='purple')
ax4.set_title('petal length')
ax4.set_xlabel('petal length')
ax4.set_ylabel('value counts')
# Out:
# Text(0, 0.5, 'value counts')

# %% [markdown]
# ## 5) 각 속성 별 IQR (Inter Quartile Range) 계산하기

# %%
percentile75_sl=df['sepal.length'].quantile(0.75)
percentile25_sl=df['sepal.length'].quantile(0.25)
IQR_sl = percentile75_sl - percentile25_sl
print('IQR of sepal length:',IQR_sl)

percentile75_sw=df['sepal.width'].quantile(0.75)
percentile25_sw=df['sepal.width'].quantile(0.25)
IQR_sw = percentile75_sw - percentile25_sw
print('IQR of sepal width:',IQR_sw)

percentile75_pl=df['petal.length'].quantile(0.75)
percentile25_pl=df['petal.length'].quantile(0.25)
IQR_pl = percentile75_pl - percentile25_pl
print('IQR of petal length:',IQR_pl)

percentile75_pw=df['petal.width'].quantile(0.75)
percentile25_pw=df['sepal.length'].quantile(0.25)
IQR_pw = percentile75_pw - percentile25_pw
print('IQR of petal width:',IQR_pw)
# Out:
# IQR of sepal length: 1.3000000000000007
# IQR of sepal width: 0.5
# IQR of petal length: 3.4999999999999996
# IQR of petal width: -3.3

# %% [markdown]
# ## 5-1) 각 속성별 40 백분위수 계산하기

# %%
import numpy as np
from sklearn.datasets import load_iris

# Iris 데이터셋 로드
iris = load_iris()
iris_data = iris.data

# Iris 데이터셋의 각 feature에 대한 40번째 백분위수 계산
percentiles_40 = np.percentile(iris_data, 40, axis=0)

print(percentiles_40)
# Out:
# [5.6  3.   3.9  1.16]

# %% [markdown]
# ##5-2) 각 속성별 히스토그램으로 분포 모양 확인하기

# %%
import matplotlib.pyplot as plt

feature_names = iris.feature_names

# 히스토그램 그리기
plt.figure(figsize=(15, 10))
for i in range(len(feature_names)):
    plt.subplot(2, 2, i+1) # 4개의 그래프가 들어갈 수 있는 그리드 생성
    plt.hist(iris_data[:, i], bins=20, color='green')
    plt.title(feature_names[i])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 5-3) Boxplot 그리기

# %%
df.boxplot()
# Out:
# <Axes: >

# %% [markdown]
# ##6-1) 바플롯으로 범주형 데이터의 탐색하기

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 범주형 데이터인 Species 추가
df['species'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# 범주별 빈도수 계산
species_counts = df['species'].value_counts()

# 빈도수 시각화
plt.figure(figsize=(10, 6))
sns.barplot(x=species_counts.index, y=species_counts.values)
plt.title('Frequency of Each Species in Iris Dataset')
plt.xlabel('Species')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## 6-2) 상관관계 계산하기

# %%
df.corr()
# Out:
# <ipython-input-33-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               sepal.length  sepal.width  petal.length  petal.width
# sepal.length      1.000000    -0.117570      0.871754     0.817941
# sepal.width      -0.117570     1.000000     -0.428440    -0.366126
# petal.length      0.871754    -0.428440      1.000000     0.962865
# petal.width       0.817941    -0.366126      0.962865     1.000000

# %% [markdown]
# ## 6-3) 상관관계 Heatmap으로 그리기 ( seaborn 활용 )

# %%
import seaborn as sns
sns.heatmap(df.corr(), annot=True)
# Out:
# <ipython-input-34-a7434eca7f55>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True)
# <Axes: >

# %% [markdown]
# ## 7) ggplot 으로 품종별 속성 데이터 비교하기
#
# - ggplot : Pivot Table 활용한 Plot
# - index가 품종인 피벗 테이블을 생성하고 ggplot 스타일을 이용해 테이블을 plot하기

# %%
table = pd.pivot_table(data=df,index=['variety'])
print(table)
plt.style.use('ggplot')
table.plot(kind='bar')
# Out:
#             petal.length  petal.width  sepal.length  sepal.width
# variety
# Setosa             1.462        0.246         5.006        3.428
# Versicolor         4.260        1.326         5.936        2.770
# virginica          5.552        2.026         6.588        2.974
# <ipython-input-36-570ccfd2af68>:1: FutureWarning: pivot_table dropped a column because it failed to aggregate. This behavior is deprecated and will raise in a future version of pandas. Select only the columns that can be aggregated.
#   table = pd.pivot_table(data=df,index=['variety'])
# <Axes: xlabel='variety'>

# %% [markdown]
# ## 8) Kdeplot 그리기
#
# - x축은 sepal length, y축은 sepal width로 설정하고 kdeplot하기

# %%
grid = sns.FacetGrid(data=df, col='variety')
grid.map(sns.kdeplot, "sepal.length", "sepal.width")

# %% [markdown]
# ## 8-1) Kdeplot 그리기
#
# - x축은 petal length, y축은 petal width로 설정하고 kdeplot하기

# %%
grid = sns.FacetGrid(data=df, col='variety')
grid.map(sns.kdeplot, "petal.length", "petal.width")
